# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import itertools
import xgboost as xgb
import numpy as np
import pandas as pd
import pickle
from sklearn.model_selection import StratifiedKFold, train_test_split
from sklearn.metrics import accuracy_score
import time
import pickle

# %%
data_directory = '/content/drive/MyDrive/FA2023/IntroToAI/jlamber4-CSE30124-Fall2023-submissions/ProjectData/'
filename = 'model_data.csv'

# %%
data = pd.read_csv(data_directory + filename).dropna()
data
# Out:
#         Unnamed: 0  batter p_throws pitch_type_condensed out_base_count_state  \
# 0                1  408234        L                   CH             2_000_22
# 1                2  408234        L                   CH             1_011_12
# 2                3  408234        L                   CH             1_000_21
# 3                4  408234        L                   CH             1_000_12
# 4                5  408234        L                   CH             0_110_21
# ...            ...     ...      ...                  ...                  ...
# 707452      707453  663609        R                   SL             2_100_12
# 707453      707454  663609        R                   SL             1_110_21
# 707454      707455  687093        R                   SL             1_000_10
# 707455      707456  644374        R                   SL             2_000_01
# 707456      707457  678545        R                   SL             2_000_01
#
#         pitcher  release_speed  release_pos_x  release_pos_z  release_pos_y  \
# 0        682227           84.1           1.01           6.17          54.52
# 1        676664           85.5           1.59           4.35          54.31
# 2        663776           81.8           1.24           5.80          54.48
# 3        669684           84.5           2.39           5.16          54.01
# 4        664285           89.4           0.66           5.96          54.29
# ...         ...            ...            ...            ...            ...
# 707452   608371           83.3          -1.90           5.70          54.77
# 707453   571656           83.2          -1.37           5.70          54.26
# 707454   663773           82.7          -1.73           6.09          53.95
# 707455   665734           86.0          -0.83           6.01          53.96
# 707456   605135           73.4          -1.84           5.30          54.37
#
#         ...  plate_x  plate_z  stand  sz_bot sz_top  events      avgEV  \
# 0       ...     0.83     3.09      R    1.80   3.56    foul  78.368750
# 1       ...     1.56     1.95      R    1.83   3.58    ball  78.368750
# 2       ...     0.69     1.09      R    1.79   3.56    ball  78.368750
# 3       ...     0.95     2.54      R    1.77   3.34  strike  78.368750
# 4       ...     0.38     3.07      R    1.82   3.47  strike  78.368750
# ...     ...      ...      ...    ...     ...    ...     ...        ...
# 707452  ...    -0.44     3.42      R    1.65   3.61    foul  80.421696
# 707453  ...    -0.29     3.95      R    1.82   3.82    ball  80.421696
# 707454  ...     0.29     0.91      R    1.64   3.36  strike  80.421696
# 707455  ...     1.75     1.41      R    1.53   3.37    ball  80.421696
# 707456  ...    -0.18     1.19      R    1.56   3.52  single  80.421696
#
#             avgLA  zSwingPCT  oSwingPCT
# 0       -9.562500   0.592593   0.232558
# 1       -9.562500   0.592593   0.232558
# 2       -9.562500   0.592593   0.232558
# 3       -9.562500   0.592593   0.232558
# 4       -9.562500   0.592593   0.232558
# ...           ...        ...        ...
# 707452  14.992125   0.682665   0.313929
# 707453  14.992125   0.682665   0.313929
# 707454  14.992125   0.682665   0.313929
# 707455  14.992125   0.682665   0.313929
# 707456  14.992125   0.682665   0.313929
#
# [704334 rows x 22 columns]

# %%
data['outs'] = data['out_base_count_state'].apply(lambda x: int(x.split('_')[0]))
data['balls'] = data['out_base_count_state'].apply(lambda x: int(x.split('_')[2][0]))
data['strikes'] = data['out_base_count_state'].apply(lambda x: int(x.split('_')[2][1]))

data.reset_index(drop=True, inplace=True)

# %%
X = data[['p_throws', 'release_speed', 'release_pos_x', 'release_pos_y', 'release_pos_z', 'pfx_x', 'pfx_z', 'plate_x', 'plate_z',
          'stand', 'sz_bot', 'sz_top', 'avgEV', 'avgLA', 'zSwingPCT', 'oSwingPCT',
          'outs', 'balls', 'strikes']]
X = pd.get_dummies(X, columns=['stand', 'p_throws'])
y = data['events'].astype('category').cat.codes
category_mapping = dict(enumerate(data['events'].astype('category').cat.categories))

# %%
param_grid = {
    'max_depth': [3, 5, 7],
    'learning_rate': [0.01, 0.05, 0.1],
    'n_estimators': [50, 100, 200]
}

all_params = [dict(zip(param_grid.keys(), v)) for v in itertools.product(*param_grid.values())]

num_folds = 5
kf = StratifiedKFold(n_splits=num_folds, shuffle=True, random_state=42)

results = []

for params in all_params:
    print(f"Testing parameters: {params}")
    fold_results = []
    fold_models = []
    fold_number = 1
    for train_index, test_index in kf.split(X, y):
        print(f"  Cross-validation fold {fold_number}/{num_folds}")
        start_time = time.time()

        X_train, X_test = X.iloc[train_index], X.iloc[test_index]
        y_train, y_test = y.iloc[train_index], y.iloc[test_index]

        model = xgb.XGBClassifier(**params, objective='multi:softprob', eval_metric='mlogloss', num_class=9, use_label_encoder=False)
        model.fit(X_train, y_train)
        fold_models.append(model)

        test_pred = model.predict(X_test)
        test_accuracy = accuracy_score(y_test, test_pred)
        fold_results.append(test_accuracy)

        end_time = time.time()
        print(f"    Completed in {end_time - start_time:.2f} seconds")
        fold_number += 1

    avg_test_accuracy = np.mean(fold_results)

    results.append({
        'params': params,
        'average_test_accuracy': avg_test_accuracy,
        'model': fold_models
    })
    print(results[-1]['average_test_accuracy'])

results_df = pd.DataFrame(results)
print(results_df)
# Out:
# Testing parameters: {'max_depth': 3, 'learning_rate': 0.01, 'n_estimators': 50}
#   Cross-validation fold 1/5
#     Completed in 32.61 seconds
#   Cross-validation fold 2/5
#     Completed in 32.08 seconds
#   Cross-validation fold 3/5
#     Completed in 32.07 seconds
#   Cross-validation fold 4/5
#     Completed in 32.11 seconds
#   Cross-validation fold 5/5
#     Completed in 32.51 seconds
# 0.5594760495173293
# Testing parameters: {'max_depth': 3, 'learning_rate': 0.01, 'n_estimators': 100}
#   Cross-validation fold 1/5
#     Completed in 63.26 seconds
#   Cross-validation fold 2/5
#     Completed in 59.78 seconds
#   Cross-validation fold 3/5
#     Completed in 62.50 seconds
#   Cross-validation fold 4/5
#     Completed in 63.09 seconds
#   Cross-validation fold 5/5
#     Completed in 62.32 seconds
# 0.5644041041748367
# Testing parameters: {'max_depth': 3, 'learning_rate': 0.01, 'n_estimators': 200}
#   Cross-validation fold 1/5
#     Completed in 119.56 seconds
#   Cross-validation fold 2/5
#     Completed in 123.57 seconds
#   Cross-validation fold 3/5
#     Completed in 118.61 seconds
#   Cross-validation fold 4/5
#     Completed in 119.14 seconds
#   Cross-validation fold 5/5
#     Completed in 122.73 seconds
# 0.5658281442360479
# Testing parameters: {'max_depth': 3, 'learning_rate': 0.05, 'n_estimators': 50}
#   Cross-validation fold 1/5
#     Completed in 32.56 seconds
#   Cross-validation fold 2/5
#     Completed in 32.37 seconds
#   Cross-validation fold 3/5
#     Completed in 32.53 seconds
#   Cross-validation fold 4/5
#     Completed in 32.05 seconds
#   Cross-validation fold 5/5
#     Completed in 32.20 seconds
# 0.5663591422249741
# Testing parameters: {'max_depth': 3, 'learning_rate': 0.05, 'n_estimators': 100}
#   Cross-validation fold 1/5
#     Completed in 58.40 seconds
#   Cross-validation fold 2/5
#     Completed in 65.03 seconds
#   Cross-validation fold 3/5
#     Completed in 65.02 seconds
#   Cross-validation fold 4/5
#     Completed in 66.23 seconds
#   Cross-validation fold 5/5
#     Completed in 65.82 seconds
# 0.572261171655889
# Testing parameters: {'max_depth': 3, 'learning_rate': 0.05, 'n_estimators': 200}
#   Cross-validation fold 1/5
#     Completed in 125.91 seconds
#   Cross-validation fold 2/5
#     Completed in 131.64 seconds
#   Cross-validation fold 3/5
#     Completed in 124.24 seconds
#   Cross-validation fold 4/5
#     Completed in 123.37 seconds
#   Cross-validation fold 5/5
#     Completed in 122.61 seconds
# 0.581087951237401
# Testing parameters: {'max_depth': 3, 'learning_rate': 0.1, 'n_estimators': 50}
#   Cross-validation fold 1/5
#     Completed in 32.25 seconds
#   Cross-validation fold 2/5
#     Completed in 32.65 seconds
#   Cross-validation fold 3/5
#     Completed in 32.57 seconds
#   Cross-validation fold 4/5
#     Completed in 32.65 seconds
#   Cross-validation fold 5/5
#     Completed in 32.17 seconds
# 0.5724670404992747
# Testing parameters: {'max_depth': 3, 'learning_rate': 0.1, 'n_estimators': 100}
#   Cross-validation fold 1/5
#     Completed in 62.16 seconds
#   Cross-validation fold 2/5
#     Completed in 58.88 seconds
#   Cross-validation fold 3/5
#     Completed in 62.71 seconds
#   Cross-validation fold 4/5
#     Completed in 62.75 seconds
#   Cross-validation fold 5/5
#     Completed in 61.31 seconds
# 0.5808366493469747
# Testing parameters: {'max_depth': 3, 'learning_rate': 0.1, 'n_estimators': 200}
#   Cross-validation fold 1/5
#     Completed in 118.87 seconds
#   Cross-validation fold 2/5
#     Completed in 119.41 seconds
#   Cross-validation fold 3/5
#     Completed in 123.33 seconds
#   Cross-validation fold 4/5
#     Completed in 119.65 seconds
#   Cross-validation fold 5/5
#     Completed in 121.35 seconds
# 0.5866350354998169
# Testing parameters: {'max_depth': 5, 'learning_rate': 0.01, 'n_estimators': 50}
#   Cross-validation fold 1/5
#     Completed in 41.78 seconds
#   Cross-validation fold 2/5
#     Completed in 39.61 seconds
#   Cross-validation fold 3/5
#     Completed in 42.15 seconds
#   Cross-validation fold 4/5
#     Completed in 39.88 seconds
#   Cross-validation fold 5/5
#     Completed in 43.81 seconds
# 0.5659985179306346
# Testing parameters: {'max_depth': 5, 'learning_rate': 0.01, 'n_estimators': 100}
#   Cross-validation fold 1/5
#     Completed in 81.33 seconds
#   Cross-validation fold 2/5
#     Completed in 82.11 seconds
#   Cross-validation fold 3/5
#     Completed in 82.99 seconds
#   Cross-validation fold 4/5
#     Completed in 82.93 seconds
#   Cross-validation fold 5/5
#     Completed in 81.08 seconds
# 0.5670065622583567
# Testing parameters: {'max_depth': 5, 'learning_rate': 0.01, 'n_estimators': 200}
#   Cross-validation fold 1/5
#     Completed in 159.69 seconds
#   Cross-validation fold 2/5
#     Completed in 159.32 seconds
#   Cross-validation fold 3/5
#     Completed in 153.96 seconds
#   Cross-validation fold 4/5
#     Completed in 159.50 seconds
#   Cross-validation fold 5/5
#     Completed in 160.83 seconds
# 0.5721305520135282
# Testing parameters: {'max_depth': 5, 'learning_rate': 0.05, 'n_estimators': 50}
#   Cross-validation fold 1/5
#     Completed in 39.44 seconds
#   Cross-validation fold 2/5
#     Completed in 44.37 seconds
#   Cross-validation fold 3/5
#     Completed in 44.74 seconds
#   Cross-validation fold 4/5
#     Completed in 39.13 seconds
#   Cross-validation fold 5/5
#     Completed in 43.69 seconds
# 0.5752100574135005
# Testing parameters: {'max_depth': 5, 'learning_rate': 0.05, 'n_estimators': 100}
#   Cross-validation fold 1/5
#     Completed in 80.93 seconds
#   Cross-validation fold 2/5
#     Completed in 80.20 seconds
#   Cross-validation fold 3/5
#     Completed in 77.71 seconds
#   Cross-validation fold 4/5
#     Completed in 78.92 seconds
#   Cross-validation fold 5/5
#     Completed in 81.87 seconds
# 0.5837557194646272
# Testing parameters: {'max_depth': 5, 'learning_rate': 0.05, 'n_estimators': 200}
#   Cross-validation fold 1/5
#     Completed in 162.15 seconds
#   Cross-validation fold 2/5
#     Completed in 163.35 seconds
#   Cross-validation fold 3/5
#     Completed in 160.38 seconds
#   Cross-validation fold 4/5
#     Completed in 156.28 seconds
#   Cross-validation fold 5/5
#     Completed in 155.92 seconds
# 0.5896165756993482
# Testing parameters: {'max_depth': 5, 'learning_rate': 0.1, 'n_estimators': 50}
#   Cross-validation fold 1/5
#     Completed in 43.52 seconds
#   Cross-validation fold 2/5
#     Completed in 39.19 seconds
#   Cross-validation fold 3/5
#     Completed in 47.47 seconds
#   Cross-validation fold 4/5
#     Completed in 43.65 seconds
#   Cross-validation fold 5/5
#     Completed in 40.35 seconds
# 0.5836975084776753
# Testing parameters: {'max_depth': 5, 'learning_rate': 0.1, 'n_estimators': 100}
#   Cross-validation fold 1/5
#     Completed in 81.07 seconds
#   Cross-validation fold 2/5
#     Completed in 80.35 seconds
#   Cross-validation fold 3/5
#     Completed in 80.42 seconds
#   Cross-validation fold 4/5
#     Completed in 80.43 seconds
#   Cross-validation fold 5/5
#     Completed in 80.29 seconds
# 0.5897997270415571
# Testing parameters: {'max_depth': 5, 'learning_rate': 0.1, 'n_estimators': 200}
#   Cross-validation fold 1/5
#     Completed in 151.47 seconds
#   Cross-validation fold 2/5
#     Completed in 155.58 seconds
#   Cross-validation fold 3/5
#     Completed in 152.54 seconds
#   Cross-validation fold 4/5
#     Completed in 157.80 seconds
#   Cross-validation fold 5/5
#     Completed in 153.36 seconds
# 0.5948016146588545
# Testing parameters: {'max_depth': 7, 'learning_rate': 0.01, 'n_estimators': 50}
#   Cross-validation fold 1/5
#     Completed in 50.15 seconds
#   Cross-validation fold 2/5
#     Completed in 50.21 seconds
#   Cross-validation fold 3/5
#     Completed in 49.64 seconds
#   Cross-validation fold 4/5
#     Completed in 50.00 seconds
#   Cross-validation fold 5/5
#     Completed in 49.13 seconds
# 0.5733245873219716
# Testing parameters: {'max_depth': 7, 'learning_rate': 0.01, 'n_estimators': 100}
#   Cross-validation fold 1/5
#     Completed in 100.58 seconds
#   Cross-validation fold 2/5
#     Completed in 99.22 seconds
#   Cross-validation fold 3/5
#     Completed in 99.07 seconds
#   Cross-validation fold 4/5
#     Completed in 103.06 seconds
#   Cross-validation fold 5/5
#     Completed in 99.83 seconds
# 0.5750751768116104
# Testing parameters: {'max_depth': 7, 'learning_rate': 0.01, 'n_estimators': 200}
#   Cross-validation fold 1/5
#     Completed in 205.57 seconds
#   Cross-validation fold 2/5
#     Completed in 200.06 seconds
#   Cross-validation fold 3/5
#     Completed in 205.18 seconds
#   Cross-validation fold 4/5
#     Completed in 202.00 seconds
#   Cross-validation fold 5/5
#     Completed in 205.41 seconds
# 0.5816842578178777
# Testing parameters: {'max_depth': 7, 'learning_rate': 0.05, 'n_estimators': 50}
#   Cross-validation fold 1/5
#     Completed in 52.35 seconds
#   Cross-validation fold 2/5
#     Completed in 52.54 seconds
#   Cross-validation fold 3/5
#     Completed in 58.18 seconds
#   Cross-validation fold 4/5
#     Completed in 51.88 seconds
#   Cross-validation fold 5/5
#     Completed in 52.64 seconds
# 0.5835825051740294
# Testing parameters: {'max_depth': 7, 'learning_rate': 0.05, 'n_estimators': 100}
#   Cross-validation fold 1/5
#     Completed in 108.12 seconds
#   Cross-validation fold 2/5
#     Completed in 102.34 seconds
#   Cross-validation fold 3/5
#     Completed in 105.44 seconds
#   Cross-validation fold 4/5
#     Completed in 101.77 seconds
#   Cross-validation fold 5/5
#     Completed in 103.12 seconds
# 0.589721638151625
# Testing parameters: {'max_depth': 7, 'learning_rate': 0.05, 'n_estimators': 200}
#   Cross-validation fold 1/5
#     Completed in 201.37 seconds
#   Cross-validation fold 2/5
#     Completed in 206.52 seconds
#   Cross-validation fold 3/5
#     Completed in 196.44 seconds
#   Cross-validation fold 4/5
#     Completed in 196.87 seconds
#   Cross-validation fold 5/5
#     Completed in 201.15 seconds
# 0.5952602042544242
# Testing parameters: {'max_depth': 7, 'learning_rate': 0.1, 'n_estimators': 50}
#   Cross-validation fold 1/5
#     Completed in 50.76 seconds
#   Cross-validation fold 2/5
#     Completed in 51.18 seconds
#   Cross-validation fold 3/5
#     Completed in 51.44 seconds
#   Cross-validation fold 4/5
#     Completed in 52.08 seconds
#   Cross-validation fold 5/5
#     Completed in 52.06 seconds
# 0.5898082446065172
# Testing parameters: {'max_depth': 7, 'learning_rate': 0.1, 'n_estimators': 100}
#   Cross-validation fold 1/5
#     Completed in 100.33 seconds
#   Cross-validation fold 2/5
#     Completed in 98.60 seconds
#   Cross-validation fold 3/5
#     Completed in 99.60 seconds
#   Cross-validation fold 4/5
#     Completed in 99.06 seconds
#   Cross-validation fold 5/5
#     Completed in 101.03 seconds
# 0.5952985375298955
# Testing parameters: {'max_depth': 7, 'learning_rate': 0.1, 'n_estimators': 200}
#   Cross-validation fold 1/5
#     Completed in 191.82 seconds
#   Cross-validation fold 2/5
#     Completed in 193.78 seconds
#   Cross-validation fold 3/5
#     Completed in 194.99 seconds
#   Cross-validation fold 4/5
#     Completed in 199.39 seconds
#   Cross-validation fold 5/5
#     Completed in 195.72 seconds
# 0.5994655940920962
#                                                params  average_test_accuracy  \
# 0   {'max_depth': 3, 'learning_rate': 0.01, 'n_est...               0.559476
# 1   {'max_depth': 3, 'learning_rate': 0.01, 'n_est...               0.564404
# 2   {'max_depth': 3, 'learning_rate': 0.01, 'n_est...               0.565828
# 3   {'max_depth': 3, 'learning_rate': 0.05, 'n_est...               0.566359
# 4   {'max_depth': 3, 'learning_rate': 0.05, 'n_est...               0.572261
# 5   {'max_depth': 3, 'learning_rate': 0.05, 'n_est...               0.581088
# 6   {'max_depth': 3, 'learning_rate': 0.1, 'n_esti...               0.572467
# 7   {'max_depth': 3, 'learning_rate': 0.1, 'n_esti...               0.580837
# 8   {'max_depth': 3, 'learning_rate': 0.1, 'n_esti...               0.586635
# 9   {'max_depth': 5, 'learning_rate': 0.01, 'n_est...               0.565999
# 10  {'max_depth': 5, 'learning_rate': 0.01, 'n_est...               0.567007
# 11  {'max_depth': 5, 'learning_rate': 0.01, 'n_est...               0.572131
# 12  {'max_depth': 5, 'learning_rate': 0.05, 'n_est...               0.575210
# 13  {'max_depth': 5, 'learning_rate': 0.05, 'n_est...               0.583756
# 14  {'max_depth': 5, 'learning_rate': 0.05, 'n_est...               0.589617
# 15  {'max_depth': 5, 'learning_rate': 0.1, 'n_esti...               0.583698
# 16  {'max_depth': 5, 'learning_rate': 0.1, 'n_esti...               0.589800
# 17  {'max_depth': 5, 'learning_rate': 0.1, 'n_esti...               0.594802
# 18  {'max_depth': 7, 'learning_rate': 0.01, 'n_est...               0.573325
# 19  {'max_depth': 7, 'learning_rate': 0.01, 'n_est...               0.575075
# 20  {'max_depth': 7, 'learning_rate': 0.01, 'n_est...               0.581684
# 21  {'max_depth': 7, 'learning_rate': 0.05, 'n_est...               0.583583
# 22  {'max_depth': 7, 'learning_rate': 0.05, 'n_est...               0.589722
# 23  {'max_depth': 7, 'learning_rate': 0.05, 'n_est...               0.595260
# 24  {'max_depth': 7, 'learning_rate': 0.1, 'n_esti...               0.589808
# 25  {'max_depth': 7, 'learning_rate': 0.1, 'n_esti...               0.595299
# 26  {'max_depth': 7, 'learning_rate': 0.1, 'n_esti...               0.599466
#
#                                                 model
# 0   [XGBClassifier(base_score=None, booster=None, ...
# 1   [XGBClassifier(base_score=None, booster=None, ...
# 2   [XGBClassifier(base_score=None, booster=None, ...
# 3   [XGBClassifier(base_score=None, booster=None, ...
# 4   [XGBClassifier(base_score=None, booster=None, ...
# 5   [XGBClassifier(base_score=None, booster=None, ...
# 6   [XGBClassifier(base_score=None, booster=None, ...
# 7   [XGBClassifier(base_score=None, booster=None, ...
# 8   [XGBClassifier(base_score=None, booster=None, ...
# 9   [XGBClassifier(base_score=None, booster=None, ...
# 10  [XGBClassifier(base_score=None, booster=None, ...
# 11  [XGBClassifier(base_score=None, booster=None, ...
# 12  [XGBClassifier(base_score=None, booster=None, ...
# 13  [XGBClassifier(base_score=None, booster=None, ...
# 14  [XGBClassifier(base_score=None, booster=None, ...
# 15  [XGBClassifier(base_score=None, booster=None, ...
# 16  [XGBClassifier(base_score=None, booster=None, ...
# 17  [XGBClassifier(base_score=None, booster=None, ...
# 18  [XGBClassifier(base_score=None, booster=None, ...
# 19  [XGBClassifier(base_score=None, booster=None, ...
# 20  [XGBClassifier(base_score=None, booster=None, ...
# 21  [XGBClassifier(base_score=None, booster=None, ...
# 22  [XGBClassifier(base_score=None, booster=None, ...
# 23  [XGBClassifier(base_score=None, booster=None, ...
# 24  [XGBClassifier(base_score=None, booster=None, ...
# 25  [XGBClassifier(base_score=None, booster=None, ...
# 26  [XGBClassifier(base_score=None, booster=None, ...

# %%
best_model_index = results_df['average_test_accuracy'].idxmax()

best_model = results_df.loc[best_model_index, 'model'][0]

print("Best Model Parameters:", results_df.loc[best_model_index, 'params'])
# Out:
# Best Model Parameters: {'max_depth': 7, 'learning_rate': 0.1, 'n_estimators': 200}

# %%
results_df
# Out:
#                                                params  average_test_accuracy  \
# 0   {'max_depth': 3, 'learning_rate': 0.01, 'n_est...               0.559476
# 1   {'max_depth': 3, 'learning_rate': 0.01, 'n_est...               0.564404
# 2   {'max_depth': 3, 'learning_rate': 0.01, 'n_est...               0.565828
# 3   {'max_depth': 3, 'learning_rate': 0.05, 'n_est...               0.566359
# 4   {'max_depth': 3, 'learning_rate': 0.05, 'n_est...               0.572261
# 5   {'max_depth': 3, 'learning_rate': 0.05, 'n_est...               0.581088
# 6   {'max_depth': 3, 'learning_rate': 0.1, 'n_esti...               0.572467
# 7   {'max_depth': 3, 'learning_rate': 0.1, 'n_esti...               0.580837
# 8   {'max_depth': 3, 'learning_rate': 0.1, 'n_esti...               0.586635
# 9   {'max_depth': 5, 'learning_rate': 0.01, 'n_est...               0.565999
# 10  {'max_depth': 5, 'learning_rate': 0.01, 'n_est...               0.567007
# 11  {'max_depth': 5, 'learning_rate': 0.01, 'n_est...               0.572131
# 12  {'max_depth': 5, 'learning_rate': 0.05, 'n_est...               0.575210
# 13  {'max_depth': 5, 'learning_rate': 0.05, 'n_est...               0.583756
# 14  {'max_depth': 5, 'learning_rate': 0.05, 'n_est...               0.589617
# 15  {'max_depth': 5, 'learning_rate': 0.1, 'n_esti...               0.583698
# 16  {'max_depth': 5, 'learning_rate': 0.1, 'n_esti...               0.589800
# 17  {'max_depth': 5, 'learning_rate': 0.1, 'n_esti...               0.594802
# 18  {'max_depth': 7, 'learning_rate': 0.01, 'n_est...               0.573325
# 19  {'max_depth': 7, 'learning_rate': 0.01, 'n_est...               0.575075
# 20  {'max_depth': 7, 'learning_rate': 0.01, 'n_est...               0.581684
# 21  {'max_depth': 7, 'learning_rate': 0.05, 'n_est...               0.583583
# 22  {'max_depth': 7, 'learning_rate': 0.05, 'n_est...               0.589722
# 23  {'max_depth': 7, 'learning_rate': 0.05, 'n_est...               0.595260
# 24  {'max_depth': 7, 'learning_rate': 0.1, 'n_esti...               0.589808
# 25  {'max_depth': 7, 'learning_rate': 0.1, 'n_esti...               0.595299
# 26  {'max_depth': 7, 'learning_rate': 0.1, 'n_esti...               0.599466
#
#                                                 model
# 0   [XGBClassifier(base_score=None, booster=None, ...
# 1   [XGBClassifier(base_score=None, booster=None, ...
# 2   [XGBClassifier(base_score=None, booster=None, ...
# 3   [XGBClassifier(base_score=None, booster=None, ...
# 4   [XGBClassifier(base_score=None, booster=None, ...
# 5   [XGBClassifier(base_score=None, booster=None, ...
# 6   [XGBClassifier(base_score=None, booster=None, ...
# 7   [XGBClassifier(base_score=None, booster=None, ...
# 8   [XGBClassifier(base_score=None, booster=None, ...
# 9   [XGBClassifier(base_score=None, booster=None, ...
# 10  [XGBClassifier(base_score=None, booster=None, ...
# 11  [XGBClassifier(base_score=None, booster=None, ...
# 12  [XGBClassifier(base_score=None, booster=None, ...
# 13  [XGBClassifier(base_score=None, booster=None, ...
# 14  [XGBClassifier(base_score=None, booster=None, ...
# 15  [XGBClassifier(base_score=None, booster=None, ...
# 16  [XGBClassifier(base_score=None, booster=None, ...
# 17  [XGBClassifier(base_score=None, booster=None, ...
# 18  [XGBClassifier(base_score=None, booster=None, ...
# 19  [XGBClassifier(base_score=None, booster=None, ...
# 20  [XGBClassifier(base_score=None, booster=None, ...
# 21  [XGBClassifier(base_score=None, booster=None, ...
# 22  [XGBClassifier(base_score=None, booster=None, ...
# 23  [XGBClassifier(base_score=None, booster=None, ...
# 24  [XGBClassifier(base_score=None, booster=None, ...
# 25  [XGBClassifier(base_score=None, booster=None, ...
# 26  [XGBClassifier(base_score=None, booster=None, ...

# %%
data_directory = '/content/drive/MyDrive/FA2023/IntroToAI/jlamber4-CSE30124-Fall2023-submissions/ProjectData/'
filename = 'best_model.pkl'

model_path = data_directory + filename

with open(model_path, 'wb') as file:
    pickle.dump(best_model, file)

print(f"Model saved successfully at {model_path}")
# Out:
# Model saved successfully at /content/drive/MyDrive/FA2023/IntroToAI/jlamber4-CSE30124-Fall2023-submissions/ProjectData/best_model.pkl

# %%
# test prediction function

def predict_outcome_probabilities(features):

    if isinstance(features, pd.Series):
        features = features.to_frame().transpose()

    probabilities = best_model.predict_proba(features)[0]

    category_names = data['events'].astype('category').cat.categories

    outcome_probabilities = {category_names[i]: prob for i, prob in enumerate(probabilities)}

    return outcome_probabilities

# %%
# testing reading in the model works

model_path = data_directory + filename

with open(model_path, 'rb') as file:
    best_model = pickle.load(file)

predict_outcome_probabilities(X.loc[1])
